# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv('tabuk22D.txt', skiprows=[0,2,3], sep='\s+')

# %%
df0.head()
# Out:
#      PRES  HGHT  TEMP  DWPT  RELH  MIXR   DRCT  SKNT   THTA   THTE   THTV
# 0  1000.0   158   NaN   NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN
# 1   933.0   768  11.0  -9.0  24.0  2.08    0.0   0.0  289.8  296.2  290.2
# 2   925.0   837  16.6  -5.4  22.0  2.78  230.0   4.0  296.3  304.9  296.8
# 3   917.0   911  19.4  -5.6  18.0  2.76  199.0   6.0  299.9  308.6  300.4
# 4   916.0   921  19.4  -5.6  18.0  2.76  195.0   6.0  300.0  308.7  300.5

# %%
df1 = pd.read_csv('tabuk22J.txt', skiprows=[0,2,3], sep='\s+')

# %%
df1.head()
# Out:
#      PRES  HGHT  TEMP  DWPT  RELH  MIXR   DRCT  SKNT   THTA   THTE   THTV
# 0  1000.0    55   NaN   NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN
# 1   925.0   755   NaN   NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN
# 2   924.0   768  27.4   7.4  28.0  7.04    0.0   0.0  307.4  329.2  308.7
# 3   922.0   787  28.8   9.8  31.0  8.31    3.0   0.0  309.0  334.8  310.6
# 4   850.0  1501  24.4   8.4  36.0  8.20  100.0   9.0  311.7  337.4  313.2

# %%
df2 = df0[['PRES']]
plt.figure(); df2.plot()
plt.plot(x=df0.HGHT)
plt.title("Presión contra Altura (22 de Dic.)")
plt.xlabel("Presión (hPa)")
plt.ylabel("Altura (m)")
plt.show()plt.grid(True)plt.grid(True)plt.grid(True)plt.grid(True)plt.grid(True)plt.grid(True)

# %%
dfh = df1[['PRES']]
plt.figure(); dfh.plot()
plt.plot(x=df1.HGHT)
plt.title("Presión contra Altura (22 de Jun.)")
plt.xlabel("Presión (hPa)")
plt.ylabel("Altura (m)")
plt.show()

# %%
df4 = df0[['TEMP', 'DWPT']]
plt.figure(); df4.plot()
plt.plot(x=df0.HGHT)
plt.title("Temper'P'PRES',RES',atura y Temperatura del Rocío en Función de la Altura (22 Dic.)")
plt.xlabel("Altura (m)")
plt.ylabel("Temp. (°C) y T. Rocío (°C)")
plt.show()

# %%
df5 = df1[['TEMP', 'DWPT']]
plt.figure(); df5.plot()2018-02-13-160615
plt.plot(x=df0.HGHT)
plt.title("Temperatura y Temperatura del Rocío en Función de la Altura (22 Jun.)")
plt.xlabel("Altura (m)")
plt.ylabel("Temp. (°C) y T. Rocío (°C)")
plt.show()

# %%
plt.figure(); df0.SKNT.plot()
plt.title("Rapidez de los Vientos (22 Dic.)")
plt.ylabel("Rapidez (Knots)")
plt.show()

# %%
2018-02-13-160615plt.figure(); df1.SKNT.plot()
plt.title("Rapidez de los Vientos (22 Jun.)")
plt.ylabel("Rapidez (Knots)")
plt.show()

# %%
dfhd = df0[['RELH']]
plt.figure(); dfhd.plot()
plt.plot(x=df0.HGHT)
plt.title("Humedad Relativa en Función de la Altura (22 Dic.)")
plt.xlabel("Altura")
plt.ylabel("Humedad Relativa (%)")
plt.show()

# %%
dfhj = df1[['RELH']]
plt.figure(); dfhj.plot()
plt.plot(x=df0.HGHT)
plt.title("Humedad Relativa en Función de la Altura (22 Jun.)")
plt.xlabel("Altura")
plt.ylabel("Humedad Relativa (%)")
plt.show()
