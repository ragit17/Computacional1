# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_csv("df2017CAPE_PW_00.csv", header=None, names=['Date', 'CAPE', 'PW'])
df.CAPE=pd.to_numeric(df.CAPE, errors='coerce')
df.PW=pd.to_numeric(df.PW, errors='coerce')
df.head()
# Out:
#          Date  CAPE    PW
# 0  05 01 2017   0.0  5.79
# 1  06 01 2017   0.0  6.47
# 2  07 01 2017   0.0  8.20
# 3  08 01 2017   0.0  4.46
# 4  11 01 2017   0.0  3.74

# %%
df['Ndate'] = pd.to_datetime(df['Date'], format='%d %m %Y')
df['month'] = df['Ndate'].dt.month
df.head()
# Out:
#          Date  CAPE    PW      Ndate  month
# 0  05 01 2017   0.0  5.79 2017-01-05      1
# 1  06 01 2017   0.0  6.47 2017-01-06      1
# 2  07 01 2017   0.0  8.20 2017-01-07      1
# 3  08 01 2017   0.0  4.46 2017-01-08      1
# 4  11 01 2017   0.0  3.74 2017-01-11      1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="CAPE", data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="PW", data=df)
plt.show()

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("CAPE", "PW", data=df, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
g = sns.lmplot(x="CAPE", y="PW", hue="month",
               truncate=True, size=5, data=df)
plt.show(g)

# %%
df = pd.read_csv("df2017CAPE_PW_12.csv", header=None, names=['Date', 'CAPE', 'PW'])
df.CAPE=pd.to_numeric(df.CAPE, errors='coerce')
df.PW=pd.to_numeric(df.PW, errors='coerce')
df.head()
# Out:
#          Date  CAPE     PW
# 0  02 01 2017   0.0   4.59
# 1  03 01 2017   0.0   5.59
# 2  04 01 2017   0.0   5.97
# 3  05 01 2017   0.0   6.22
# 4  06 01 2017   0.0  13.07

# %%
df['Ndate'] = pd.to_datetime(df['Date'], format='%d %m %Y')
df['month'] = df['Ndate'].dt.month
df.head()
# Out:
#          Date  CAPE     PW      Ndate  month
# 0  02 01 2017   0.0   4.59 2017-01-02      1
# 1  03 01 2017   0.0   5.59 2017-01-03      1
# 2  04 01 2017   0.0   5.97 2017-01-04      1
# 3  05 01 2017   0.0   6.22 2017-01-05      1
# 4  06 01 2017   0.0  13.07 2017-01-06      1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="CAPE", data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="PW", data=df)
plt.show()

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("CAPE", "PW", data=df, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
g = sns.lmplot(x="CAPE", y="PW", hue="month",
               truncate=True, size=5, data=df)
plt.show(g)
